# %%
from q1 import convolucao, filtroMedia
from imagem import Imagem
from skimage.io import imread,imsave,imshow
import cv2
import numpy as np
import matplotlib.pyplot as plt
from skimage.util import random_noise

# %%
img = Imagem(name='sunflower.jpg')
img.ler()

# %%
def nitidez(imagem, k):
    media = convolucao(imagem, filtroMedia, 'padding')
    mascara = imagem - media
    resultado = imagem + (k * mascara)

    img.manyShowWithTitle(
        {'img': imagem, 'title': f'Imagem original'},
        {'img': media, 'title': f'Média'},
        {'img': mascara, 'title': f'Máscara'},
        {'img': resultado, 'title': f'Imagem com nitidez\nk = {k}'},
        color='gray'
    )

# %%
img.imgRed
# Out:
# array([[[0.30980392, 0.40392157, 0.34117647],
#         [0.35490196, 0.45490196, 0.38627451],
#         [0.3379085 , 0.4503268 , 0.37254902],
#         ...,
#         [0.25620915, 0.37385621, 0.27712418],
#         [0.28039216, 0.4       , 0.28235294],
#         [0.32418301, 0.44575163, 0.31372549]],
#
#        [[0.08562092, 0.15620915, 0.09346406],
#         [0.22941176, 0.30588235, 0.24117647],
#         [0.28496732, 0.36732026, 0.30065359],
#         ...,
#         [0.23986928, 0.34248366, 0.29019608],
#         [0.2627451 , 0.36862745, 0.30196078],
#         [0.25294118, 0.3620915 , 0.27777778]],
#
#        [[0.06470588, 0.11960784, 0.05294118],
#         [0.10588235, 0.16078431, 0.09411765],
#         [0.09150327, 0.14640523, 0.07973856],
#         ...,
#         [0.32156863, 0.41960784, 0.3372549 ],
#         [0.30980392, 0.40980392, 0.31960784],
#         [0.27843137, 0.38039216, 0.28235294]],
#
#        ...,
#
#        [[0.17908497, 0.29477124, 0.20392157],
#         [0.22352941, 0.32156863, 0.25294118],
#         [0.26143791, 0.35816993, 0.28562091],
#         ...,
#         [0.34575163, 0.47254902, 0.38169935],
#         [0.36470588, 0.49607843, 0.4117647 ],
#         [0.22026144, 0.35294118, 0.2882353 ]],
#
#        [[0.26666667, 0.38300654, 0.28366013],
#         [0.26862745, 0.36862745, 0.29019608],
#         [0.23137255, 0.32156863, 0.25098039],
#         ...,
#         [0.36078431, 0.48627451, 0.39607843],
#         [0.37647059, 0.50392157, 0.42156863],
#         [0.32352941, 0.45620915, 0.39150327]],
#
#        [[0.28562091, 0.4       , 0.30130719],
#         [0.26470588, 0.35882353, 0.28235294],
#         [0.24705882, 0.3372549 , 0.26666667],
#         ...,
#         [0.35816993, 0.48366013, 0.39346405],
#         [0.35098039, 0.47843137, 0.39607843],
#         [0.37973856, 0.5124183 , 0.44771242]]])

# %%
for k in [0.2, 0.5, 1.0, 1.5, 2.0]:
    nitidez(img.imgGray, k)
# Out:
# 0.011328976033752365
# 0.011328976033752365
# 0.011328976033752365
# 0.011328976033752365
# 0.011328976033752365

# %%
for k in [0.2, 0.5, 1.0, 1.5, 2.0]:
    nitidez(img.imgRed, k)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# [0 0 0]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# [0 0 0]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# [0 0 0]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# [0 0 0]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# [0 0 0]
