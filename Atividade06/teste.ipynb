# %%
from montaDataset import pegaData
from imagem import Imagem
from otsu_niblack import otsu, niblack
from matplotlib import pyplot as plt #para plotar os gráficos
from aplicaKM import aplicaKM
from sklearn.cluster import KMeans #para usar o KMeans

# %%
aux = pegaData('ultrassound/cropped/')

# %%
aux[0]
# Out:
# 'ultrassound/cropped/1100212031.bmp'

# %%
a = Imagem(aux[1])
a.ler()

# %%
kmeans = KMeans(n_clusters = 2)

# %%
plt.imshow(aplicaKM(kmeans, a.dimensoes[0]), cmap='gray')

# %% [markdown]
# # B) da 1

# %%
o = otsu(a.dimensoes[0])
n = niblack(a.dimensoes[0], ws=25, k=0.8)

# %%
Imagem().manyShow(a.img, a.dimensoes[0], o, n, color='gray')
