# %%
from nao_lineares import nao_linear
from imagem import Imagem
from skimage.io import imread,imsave,imshow
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = Imagem(name='./sunflower.jpg')
img.ler()
img.show()

# %%
imagem = cv2.imread('./sunflower.jpg').astype(np.uint8)
imagemRed = cv2.resize(imagem, (240, 240))
teste = cv2.cvtColor(imagemRed, cv2.COLOR_BGR2RGB)

# %%
imagem
# Out:
# array([[[ 85, 101,  77],
#         [ 97, 113,  89],
#         [100, 119,  92],
#         ...,
#         [ 69,  97,  67],
#         [ 75, 107,  76],
#         [ 81, 115,  84]],
#
#        [[ 19,  35,  17],
#         [ 48,  64,  46],
#         [ 75,  92,  71],
#         ...,
#         [ 79,  94,  67],
#         [ 75,  94,  67],
#         [ 70,  92,  64]],
#
#        [[ 12,  29,  15],
#         [ 21,  38,  24],
#         [ 27,  44,  30],
#         ...,
#         [ 86, 107,  82],
#         [ 77, 102,  76],
#         [ 71,  96,  70]],
#
#        ...,
#
#        [[ 50,  74,  44],
#         [ 62,  81,  54],
#         [ 67,  83,  60],
#         ...,
#         [109, 133,  99],
#         [101, 120,  87],
#         [ 68,  84,  50]],
#
#        [[ 72,  98,  68],
#         [ 74,  96,  68],
#         [ 74,  92,  69],
#         ...,
#         [106, 129,  97],
#         [109, 128,  95],
#         [ 98, 114,  80]],
#
#        [[ 78, 104,  74],
#         [ 71,  92,  67],
#         [ 73,  91,  68],
# ...

# %%
plt.imshow(teste)

# %%
media = nao_linear(teste, 5, 5, 'a')
# Out:
# ...
# 100%|██████████| 240/240 [00:01<00:00, 169.94it/s]

# %%
imshow(media, cmap='gray')

# %%
mediana = nao_linear(teste, 3, 3, 'b')
imshow(mediana, cmap='gray')
# Out:
# ...
# 100%|██████████| 240/240 [00:00<00:00, 478.76it/s]

# %%
maximo = nao_linear(teste, 3, 3, 'c')
imshow(maximo, cmap='gray')
maximo
# Out:
# ...
# 100%|██████████| 240/240 [00:00<00:00, 502.87it/s]
# array([[[ 91, 116,  99],
#         [ 91, 116,  99],
#         [ 91, 116,  99],
#         ...,
#         [168, 178, 152],
#         [168, 178, 152],
#         [168, 178, 152]],
#
#        [[ 91, 116,  99],
#         [ 91, 116,  99],
#         [ 91, 119,  99],
#         ...,
#         [168, 188, 152],
#         [168, 188, 152],
#         [168, 188, 152]],
#
#        [[ 91, 116,  99],
#         [ 91, 119,  99],
#         [ 91, 119,  99],
#         ...,
#         [169, 190, 152],
#         [169, 190, 152],
#         [169, 190, 152]],
#
#        ...,
#
#        [[255, 255, 177],
#         [255, 255, 177],
#         [255, 255, 177],
#         ...,
#         [255, 255, 183],
#         [255, 255, 183],
#         [255, 255, 183]],
#
#        [[255, 255, 177],
#         [255, 255, 177],
#         [255, 255, 177],
#         ...,
#         [255, 255, 183],
#         [255, 255, 183],
#         [255, 255, 183]],
#
#        [[255, 255, 177],
# ...

# %%
minimo = nao_linear(teste, 3, 3, 'd')
imshow(minimo, cmap='gray')
# Out:
# ...
# 100%|██████████| 240/240 [00:00<00:00, 529.87it/s]
